# %%
valor = input()
# Out:
# algo

# %%
valor
# Out:
# 'algo'

# %%
valor = input()
# Out:
# 100

# %%
valor = input("introduce un valor: ")
# Out:
# introduce un valor: 100

# %%
valor = input("introduce un numero entero: ")
# Out:
# introduce un numero entero: 500

# %%
valor
# Out:
# '500'

# %% [markdown]
# para transformar el contenido del input de tipo string a otro tipo de dato

# %%
valor = int(valor)

# %%
valor = input("introduce un valor tipo flotante: ")
# Out:
# introduce un valor tipo flotante: 10.50

# %%
valor = float(valor)
valor
# Out:
# 10.5

# %%
valor = int(input("ingresa un valor de tipo entero: "))
# Out:
# ingresa un valor de tipo entero: 5

# %%
valor = float(input("ingrese un valor de tipo flotante: "))
# Out:
# ingrese un valor de tipo flotante: 3.1416
