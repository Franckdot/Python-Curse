# %%
# Las tuplas son inmutablas
tupla = (100, "Hola", [1,2,3,4], -50)
tupla
# Out:
# (100, 'Hola', [1, 2, 3, 4], -50)

# %%
tupla[0]
# Out:
# 100

# %%
tupla[-1]
# Out:
# -50

# %%
tupla[2][-1]
# Out:
# 4

# %%
tupla[0] = 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ee14e4cbf604> in <cell line: 0>()
# ----> 1 tupla[0] = 50
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(tupla)
# Out:
# 4

# %%
len(tupla[2])
# Out:
# 4

# %%
tupla
# Out:
# (100, 'Hola', [1, 2, 3, 4], -50)

# %%
# Se puede usar index y buscar algun valor, pero si no existe en la tupla da error
tupla.index('Hola')
# Out:
# 1

# %%
tupla.index('Otro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-032962c4b3a2> in <cell line: 0>()
# ----> 1 tupla.index('Otro')
#
# ValueError: tuple.index(x): x not in tuple

# %%
tupla.count(100)
# Out:
# 1

# %%
tupla.count('Algo')
# Out:
# 0

# %%
tupla = (100,100,50,10)

# %%
tupla.count(100)
# Out:
# 2

# %%
# la tupla no puede usar el append
tupla.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e79e1a7e30e9> in <cell line: 0>()
#       1 # la tupla no puede usar el append
# ----> 2 tupla.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'
