# %%
#Los Conjuntos son coleccion de elementos unicos,
#Se utiliza para validar pertenecia y eleminiacion de elementos dulpicados
conjunto = set()
conjunto
# Out:
# set()

# %%
conjunto = {1,2,3}
conjunto
# Out:
# {1, 2, 3}

# %%
#Se dice que los conjuntos son desordenados porque a medida
#que añadimos elementos a un conjunto, este orden no se conserva.
#el metodo mas utilizado es el add
conjunto.add(4)
conjunto
# Out:
# {1, 2, 3, 4}

# %%
conjunto.add(0)
conjunto
# Out:
# {0, 1, 2, 3, 4}

# %%
conjunto.add('H')
conjunto
# Out:
# {0, 1, 2, 3, 4, 'H'}

# %%
conjunto.add('a')
conjunto
# Out:
# {0, 1, 2, 3, 4, 'H', 'a'}

# %%
conjunto.add('A')
conjunto
# Out:
# {0, 1, 2, 3, 4, 'A', 'H', 'a'}

# %%
# Para buscar en el conjunto
grupo = {'Hector','Juan','Mario'}
'Hector' in grupo
# Out:
# True

# %%
'Maria' in grupo
# Out:
# False

# %%
'Hector' not in grupo
# Out:
# False

# %%
#Elimina duplicados
test = {'Hector','Hector','Hector'}
test
# Out:
# {'Hector'}

# %%
# Transformaremos una lista en un conjunto para aprovechar la eliminacion de duplicados
#Primero generamos la lista
estoUnaLista = [1,2,3,3,2,1]
estoUnaLista
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
#Hacemos el cambio de una lista a un conjunto
estoEsUnConjunto = set(estoUnaLista)
estoEsUnConjunto
# Out:
# {1, 2, 3}

# %%
#Si nuestro interes es seguir trabajando con la lista, volvemos a hacer el cambio
#vuala, quedo una lista sin duplicados
estoUnaLista = list(estoEsUnConjunto)
estoUnaLista
# Out:
# [1, 2, 3]

# %%
estoUnaLista = [1,2,3,3,2,1]
estoUnaLista = list( set(estoUnaLista))
estoUnaLista
# Out:
# [1, 2, 3]

# %%
#Este concepto, tambien funciona con cadena de caracteres
estoEsString = "Al pan pan y al vino vino"
set(estoEsString)
# Out:
# {' ', 'A', 'a', 'i', 'l', 'n', 'o', 'p', 'v', 'y'}
