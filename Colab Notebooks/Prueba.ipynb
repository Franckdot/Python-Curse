# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# hola, este es mi primer cuaderno
#
# **Lorem ipsum....**

# %%
# Esto es una celda en markdown

# %%
print("print es una instruccion que muestra texto por pantalla")
# Out:
# print es una instruccion que muestra texto por pantalla

# %%
# suma
3+2
# Out:
# 5

# %%
# resta
3-2
# Out:
# 1

# %%
# multiplicacion
3*2
# Out:
# 6

# %%
#modulo
3%2
# Out:
# 1

# %%
# potencia
3**2
# Out:
# 9

# %%
# Respeta el orden de las operaciones
3-2+4*10
# Out:
# 41

# %%
# Flotante
3323235486.2356548546
# Out:
# 3323235486.235655

# %%
# Asignacion de un valor a una variable
n = 3
n
# Out:
# 3

# %%
n+3
# Out:
# 6

# %%
n*n
# Out:
# 9

# %%
m=10

# %%
m+n
# Out:
# 13

# %%
n=10
m=15
n+m
# Out:
# 25

# %% [markdown]
# **Requisitos para nombrar una variable**
# - las variables no pueden comenzar con un numero
# - No puede contener espacios
# - tampoco simbolos especiales (a´, e´, o´u´, ?,¡,¿, etc)
# - podemos utilizar "_" para los espacios

# %%
nota_1 = 7.5
nota_2 = 10
nota_media = (nota_1 + nota_2) / 2
nota_media
# Out:
# 8.75
