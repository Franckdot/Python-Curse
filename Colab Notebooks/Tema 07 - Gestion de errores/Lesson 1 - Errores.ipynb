# %%
# Existen varios tipos de errores
# Ejemplo los sintaticos
print("Hola"
# Out:
#   File "<ipython-input-2-b05437ee445f>", line 1
#     print("Hola"
#                 ^
# SyntaxError: incomplete input

# %%
prit("Hola")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-254f97ca28b0> in <cell line: 0>()
# ----> 1 prit("Hola")
#
# NameError: name 'prit' is not defined

# %%
# Otro tipo de errores, son los errores semanticos
# Son erres que no funcionan como se espera
l=[1,2,3]
l.pop()
l.pop()
l.pop()
# Out:
# 1

# %%
# Este error ocurre porque la lista se quedo sin elementos en el paso anterior
# Una forma de mitigarlo es validar si existe algo en la lista
l.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-33a5ac1f2384> in <cell line: 0>()
# ----> 1 l.pop()
#
# IndexError: pop from empty list

# %%
# Nuevamente declararemos la lista y vamos a validar primero

l=[1,2,3]

# %%
if len(l) > 0:
  l.pop()
l
# Out:
# []

# %%
n = input("Introduce un numero: ")
# Out:
# Introduce un numero: 4

# %%
m = 4

# %%
# Del imput se recive una cadena, lo primero que se debe hacer convertirlo a entero
print("{}/{}={}".format(n,m,n/m))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-66c32f9fdef2> in <cell line: 0>()
# ----> 1 print("{}/{}={}".format(n,m,n/m))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
#Se convierte y ahora si se puede hacer el cambio
n = float(input("Introduce un numero: "))
m = 4
print("{}/{}={}".format(n,m,n/m))

# Pero podria ocurri un error si el usuario no mete un numero correcto
# Por ejemplo, si introduce letras, la conversion no se podria hacer y saltaria una excepcion
# Out:
# Introduce un numero: aaa
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-6bdf387dc3b3> in <cell line: 0>()
#       1 #Se convierte y ahora si se puede hacer el cambio
# ----> 2 n = float(input("Introduce un numero: "))
#       3 m = 4
#       4 print("{}/{}={}".format(n,m,n/m))
#       5
#
# ValueError: could not convert string to float: 'aaa'
