# %%
# Excepcion generica guardada en una variable
try:
  n = input("Introduce un numero: ")
  5/n
except Exception as e:
  print(type(e).__name__)
# Out:
# Introduce un numero: a
# TypeError

# %%
try:
  n = input("Introduce un numero: ")
  5/n
except TypeError:
  print("No se puede dividir el numero por una cadena")
except ValueError:
  print("Debes introducir una cadena que sea un numero")
except Exception as e:
  print( type(e).__name__ )
# Out:
# Introduce un numero: 0
# No se puede dividir el numero por una cadena

# %%
try:
  n = float(input("Introduce un numero: "))
  5/n
except TypeError:
  print("No se puede dividir el numero por una cadena")
except ValueError:
  print("Debes introducir una cadena que sea un numero")
except ZeroDivisionError:
  print("No se puede dividir por cero una cadena")
except Exception as e:
  print( type(e).__name__ )
# Out:
# Introduce un numero: aaa
# Debes introducir una cadena que sea un numero
