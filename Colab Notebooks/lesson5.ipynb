# %%
a = 0

# %%
# suma en asignacion
a += 5
a
# Out:
# 10

# %%
# resta en asignacion
a -= 10
a
# Out:
# 0

# %%
 # producto en asignacion
a = 5
a *= 2
a
# Out:
# 10

# %%
# division en asignacion
a /= 2
a
# Out:
# 5.0

# %%
# modulo en asignacion
a %= 2
a
# Out:
# 1.0

# %%
a **= 10
a
# Out:
# 1.0

# %%
a = 5
a **= 5
a
# Out:
# 3125
