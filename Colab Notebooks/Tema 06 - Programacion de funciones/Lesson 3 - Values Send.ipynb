# %%
def suma(a,b):
  return a+b
# Los valores dentro de los parentecis al definir la funcion se les llama paranetros

# %%
r = suma(2, 5)
r
# Y cuando se estan agregando los valores en la llamada se les llama argumentos
# Out:
# 7
