# %%
# Sirven para cambiar tipos de datos
n = int("10")
n
# Out:
# 10

# %%
f = float("10.5")
f
# Out:
# 10.5

# %%
c = "un texto y un numero" + str(10) + " " + str(3.14)
c
# Out:
# 'un texto y un numero10 3.14'

# %%
# Pasar un numero entero a binario
bin(10)
# El resultado muestra 0b1010 los dos primeros digitos indican que es un numero binario
#y las siguientes 4 indican la representacion de dicho numero de la funcion
# Out:
# '0b1010'

# %%
# Indica cual es el valor del numero dado en exadecimal
hex(10)
# Out:
# '0xa'

# %%
# podemos convertir al contrario de binario a decimal o numeros enteros
# se da el numero en binario y la base 2
int('0b1010', 2)
# Out:
# 10

# %%
# Se convierte de exadecimal a decimal, dando la conversion y la base en hexadecimal que es 16
int('0xa', 16)
# Out:
# 10

# %%
# Valor absoluto, cuenta la distacia que hay hasta el cero, se diria que es como quitar el signo menos
abs(-10)
# Out:
# 10

# %%
abs(10)
# Out:
# 10

# %%
# funcion que redondea hacia arriba
round(5.5)
# Out:
# 6

# %%
# FUncion que redondea hacia abajo
round(5.4)
# Out:
# 5

# %%
# Eval interpreta las cadenas y hace las operaciones
eval('2+5')
# Out:
# 7

# %%
# soporta variables
eval('n*10-5')
# Out:
# 95

# %%
# permite saber la lungitud de una cadena o lista
len("Una cadena")
# Out:
# 10

# %%
len([])
# Out:
# 0

# %%
# Funcion que te permite optener ayuda cuando no tienes acceso a internet por ejemplo
help()
# Out:
# Welcome to Python 3.11's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.11/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.
