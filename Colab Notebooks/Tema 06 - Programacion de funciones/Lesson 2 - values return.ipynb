# %%
def test():
  return "Una cadena retornada"

test()
# Out:
# 'Una cadena retornada'

# %% [markdown]
# Al utilizar el return, la funcion devolvera el valor y finalizara en ese momento
# como cuando utilizamos un breack en una iteracion, el demas codigo no se ejecutara nunca
# El Return se puede utilzar como si fuera un valor del tipo de dato que devuelve

# %%
print(test())
# Out:
# Una cadena retornada

# %%
c = test()

# %%
print(c)
# Out:
# Una cadena retornada

# %%
c=test() +10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f1ce1fb821b3> in <cell line: 0>()
# ----> 1 c=test() +10
#
# TypeError: can only concatenate str (not "int") to str

# %%
def test():
  return [1,2,3,4,5]

print(test())
# Out:
# [1, 2, 3, 4, 5]

# %%
print(test()[-1])
# Out:
# 5

# %%
print(test()[1:4])
# Out:
# [2, 3, 4]

# %%
l = test()
l[-1]
# Out:
# 5

# %%
def test():
  return "Una cadena",20,[1,2,3]

test()
# Out:
# ('Una cadena', 20, [1, 2, 3])

# %%
c,n,l = test()
c
# Out:
# 'Una cadena'

# %%
n
# Out:
# 20

# %%
l
# Out:
# [1, 2, 3]
