# %%
#para definir una funcion es asi:
def saludar():
  print("Hola! este print se llama desde de la funcion saludar")

saludar()
# Out:
# Hola! este print se llama desde de la funcion saludar

# %% [markdown]
# Para nombrar las funciones se utilizan minusculas y guines bajos para separa palabras y utilizar nombres autoexplicativos

# %%
def dibujar_tabla_del_5():
  for i in range(10):
    print( "5 x ", i," = ", i * 5)

dibujar_tabla_del_5()
# Out:
# 5 x  0  =  0
# 5 x  1  =  5
# 5 x  2  =  10
# 5 x  3  =  15
# 5 x  4  =  20
# 5 x  5  =  25
# 5 x  6  =  30
# 5 x  7  =  35
# 5 x  8  =  40
# 5 x  9  =  45

# %%
def test():
  n=10
test()

# %%
print(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-349653be3a92> in <cell line: 0>()
# ----> 1 print(n)
#
# NameError: name 'n' is not defined

# %%
n=10
def test():
  print(n)
test()
# Out:
# 10

# %%
def test():
  print(l)
l=10
test()
# Out:
# 10

# %%
def test():
  o=5
  print(o)
test()

o=10
test()
print(o)
# Variables con el mismo nombre pueden coexistir en el mismo codigo
# Out:
# 5
# 5
# 10
