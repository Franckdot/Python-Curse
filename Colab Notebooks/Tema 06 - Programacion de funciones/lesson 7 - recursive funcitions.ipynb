# %%
# La recursividad es una tecnica utilizada para que cuando una actividad sea dificil
# se divida en partes mas pequeñas que se puedan resolver.
# funciones recursiva sin retorno y con retorno
# Una caracteristicas de las funciones recursivas, esque se llaman a si mismas
def cuenta_atras(num):
  num -= 1
  if num > 0:
    print(num)
    cuenta_atras(num)
  else:
    print("Boooooom!")
  print("Fin de la funcion: ", num)

cuenta_atras(5)
# Out:
# 4
# 3
# 2
# 1
# Boooooom!
# Fin de la funcion:  0
# Fin de la funcion:  1
# Fin de la funcion:  2
# Fin de la funcion:  3
# Fin de la funcion:  4

# %%
def factorial(num):
  if num > 1:
    num = num * factorial(num -1)
  return num

factorial(5)
# Out:
# 120

# %%
def factorial(num):
  print("Valor inicial ->", num)
  if num > 1:
    num = num * factorial(num -1)
  print("valor final -> ", num)
  return num

factorial(5)
# Out:
# Valor inicial -> 5
# Valor inicial -> 4
# Valor inicial -> 3
# Valor inicial -> 2
# Valor inicial -> 1
# valor final ->  1
# valor final ->  2
# valor final ->  6
# valor final ->  24
# valor final ->  120
# 120
