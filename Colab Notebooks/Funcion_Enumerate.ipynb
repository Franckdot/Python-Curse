# %%
elementos = ["Hola", 4, "Adios", [1,2,3]]
for e in elementos:
  print(e)
# Out:
# Hola
# 4
# Adios
# [1, 2, 3]

# %%
for i, e in enumerate(elementos):
  print(i, e)
# Out:
# 0 Hola
# 1 4
# 2 Adios
# 3 [1, 2, 3]

# %%
a, b, c = 10, 50, 100
print(a,b,c)
# Out:
# 10 50 100

# %%
(a,b,c) = (10, 50, 100)
print(a,b,c)
# Out:
# 10 50 100

# %%
[a,b,c] = [10, 50, 100]
print(a)
# Out:
# 10

# %%
def funcion():
  return 10, 20, 50

  a,b,c = funcion()
a,b,c
# Out:
# (10, 50, 100)

# %%
list(enumerate(elementos))
# Out:
# [(0, 'Hola'), (1, 4), (2, 'Adios'), (3, [1, 2, 3])]

# %%
for tupla in enumerate(elementos):
  print(tupla)
# Out:
# (0, 'Hola')
# (1, 4)
# (2, 'Adios')
# (3, [1, 2, 3])

# %%
# Enumerate tranforma una lista con su valor
