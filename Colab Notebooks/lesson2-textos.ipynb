# %%
'Hola Mundo'
# Out:
# 'Hola Mundo'

# %%
"Hola Mundo"
# Out:
# 'Hola Mundo'

# %%
'Este texto incluye unas "" '
# Out:
# 'Este texto incluye unas "" '

# %%
"Esta 'palabra' se encuentra escrita entre comillas simples "
# Out:
# "Esta 'palabra' se encuentra escrita entre comillas simples "

# %%
"Esta \"palabra\" se encuentra entre comillas dobles "
# Out:
# 'Esta "palabra" se encuentra entre comillas dobles '

# %%
'Esta \'palabra\' se encuentra entre comillas simples'

# %%
"Una cadena"
'otra cadena'
'otra cedena mas'
# Out:
# 'otra cedena mas'

# %%
print("una cadena")
print('otra cadena')
print('otra cadena mas')
# Out:
# una cadena
# otra cadena
# otra cadena mas

# %%
print("Un texto \tuna tabulacion")
# Out:
# Un texto 	una tabulacion

# %%
print("Un texto\nuna nueva linea")
# Out:
# Un texto
# una nueva linea

# %%
print(r"c:\nombre\directorio")
# Out:
# c:\nombre\directorio

# %% [markdown]
# \t
# \n
# r"\t"
# estas nos permiten hacer una tabulacion, un salto de linea, y la r nos permite decirle que no tome los carateres especiales.

# %%
print("""una line
otra linea
otra linea\tuna tabulacion""")
# Out:
# una line
# otra linea
#       otra linea	una tabulacion

# %%
c = "Esto es una cadena\ncon dos lineas"

# %%
c
# Out:
# 'Esto es una cadena\ncon dos lineas'

# %%
print(c)
# Out:
# Esto es una cadena
# con dos lineas

# %%
c + c
# Out:
# 'Esto es una cadena\ncon dos lineasEsto es una cadena\ncon dos lineas'

# %%
print(c + c)
# Out:
# Esto es una cadena
# con dos lineasEsto es una cadena
# con dos lineas

# %%
s = "Una cadena" " compuesta de dos cadenas"
print(s)
# Out:
# Una cadena compuesta de dos cadenas

# %%
c1 = "Una Cadena"
c2 = "otra cadena"
print("una cadena" + c2)
# Out:
# una cadenaotra cadena

# %%
diez_espacios = " " * 10
print(diez_espacios + "un texto a diez espacios")
# Out:
#           un texto a diez espacios

# %% [markdown]
# Indices
#
# +---+---+---+---+---+---+
#
# | P | Y | T | H | O | N |
#
# +---+---+---+---+---+---+
#
# 0   1   2   3   4   5   6
#
# Es como si la cadena se convirtiera en un tipo de arreglo donde podemos extraer una parte de la

# %%
palabra = "Python"

# %%
# Caracte en la posicion 0
palabra[0]
# Out:
# 'P'

# %%
palabra[3]
# Out:
# 'h'

# %%
# Se pueden usar indices en negativo para volcar los caracteres al contrario
palabra[-1]
# Out:
# 'n'

# %%
palabra[-2]
# Out:
# 'o'

# %%
palabra[-6]
# Out:
# 'P'

# %%
# Soporta multiples indices con la instruccion slicing
