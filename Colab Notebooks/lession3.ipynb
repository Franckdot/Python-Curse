# %% [markdown]
# Listas

# %%
numero = [1,2,3,4]

# %%
datos = [4, "una cadena", -15,3.14, "otra cadena"]

# %%
datos[0]
# Out:
# 4

# %%
datos[-1]
# Out:
# 'otra cadena'

# %%
datos[-2:]
# Out:
# [3.14, 'otra cadena']

# %%
numero + [5,6,7,8]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# las cadenas de caracteres son inmutables pero las litas no lo son.

# %%
# lista
pares = [0,2,4,5,8,10]

# %%
pares[3]=6
pares
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
pares.append(12)
pares
# Out:
# [0, 2, 4, 6, 8, 10, 12]

# %%
pares.append(7*2)
pares
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
letras = ['a','b','c','d']
letras[:3]
# Out:
# ['a', 'b', 'c']

# %%
letras[:3] = ['A', 'B', 'C']

# %%
letras
# Out:
# ['A', 'B', 'C', 'd']

# %%
letras[:3] = []
letras
# Out:
# ['d']

# %%
len(letras)
# Out:
# 1

# %% [markdown]
# listas anidadas

# %%
a=[1,2,3]
b=[4,5,6]
c=[7,8,9]
r=[a,b,c]

# %%
r
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
r[0]
# Out:
# [1, 2, 3]

# %%
r[-1]
# Out:
# [7, 8, 9]

# %%
r[0][0]
# Out:
# 1

# %%
r[2][2]
# Out:
# 9

# %%
miPrimerArreglo = [3,7,2,1,8,5,4,6]
jk = miPrimerArreglo[0] + miPrimerArreglo[1]
jk
# Out:
# 10
