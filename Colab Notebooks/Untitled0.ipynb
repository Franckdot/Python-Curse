# %%
n = 0
while n < 10:
  if(n % 2) == 0:
    print(n, 'es un numero par')
  else:
    print(n, 'es un numero impar')
  n = n + 1
# Out:
# 0 es un numero par
# 1 es un numero impar
# 2 es un numero par
# 3 es un numero impar
# 4 es un numero par
# 5 es un numero impar
# 6 es un numero par
# 7 es un numero impar
# 8 es un numero par
# 9 es un numero impar

# %%
# Operadores relacionales
# Igual que
3 == 2
# Distinto de
3 != 2
# Mayor que
3 > 2
# Menor que
3 < 2
# Mayor o igual que
3 >= 2
# Menor o Igual que
3 <= 2
# tambien se puede hacer con los valores que ocupan una variable
a = 10
b = 5
a > b
b != a
a == b*2
# Se puede hacer con cadenas de texto
"Hola" == "Hola"
"Hola" != "Hola"
c = "Hola"
c[0] == "H"
c[-1] == "a"
# Comparar listas y elementos
l1 = [0,1,2]
l2 = [2,3,4]
l1 == l2
# Out:
# False

# %%
len(l1) == len(l2)
# Out:
# True

# %%
l1[-1] == l2[0]
# Out:
# True

# %%
# Logicos
True == True
# Out:
# True

# %%
False == True
# Out:
# False

# %%
False != True
# Out:
# True

# %%
# esto es porque tienen un valor asignado, True = 1 y False = 0
True > False
# Out:
# True

# %%
True < False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not True == False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
a = 45
a > 10 and a < 20
# Out:
# True

# %%
c = "Hola Mundo"
len(c) >= 20 and C[0] == 'H'
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
c = "SALIR"
c == "EXIT" or c == "FIN" or c == "SALIR"

# %%
c = "Hector"
c[0] == "H"
# Out:
# True

# %%
# Expresiones anidadadas
# normas de presedencias que lo que nos dice que hay que resolver primero lo de los parentesis
a = 10
b = 5
a * b - 2**b >= 20 and not (a % b) != 0
# Out:
# False
